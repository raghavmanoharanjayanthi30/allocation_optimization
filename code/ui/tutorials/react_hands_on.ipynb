# %% [markdown]
# # React Hands-On\n\nThis notebook is a guided checklist while editing `code/ui/frontend/src/App.jsx`.\n\n## Start frontend\n```bash\ncd code/ui/frontend\nnpm install\nnpm run dev\n```

# %% [markdown]
# ## Exercise 1: Add controls\n- Add two numeric inputs in `App.jsx`:\n  - technician count\n  - job count\n- Use these values in `handleGenerate()` payload.

# %% [markdown]
# ## Exercise 2: Better result summary\n- Add assignment rate: `assigned / total_jobs`.\n- Add a small table showing the first 5 assignments (`technician_id`, `request_id`, `score`).

# %% [markdown]
# ## Exercise 3: Compare algorithms quickly\n- Add a button `Run all methods`.\n- Loop through methods from `/methods` and show a compact comparison table.
